# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Data_Sets/1.1 Automobile.csv.csv')

# %%
data.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
data['make']                           # Used to print particular column.
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 196          volvo
# 197          volvo
# 198          volvo
# 199          volvo
# 200          volvo
# Name: make, Length: 201, dtype: object

# %%
data.columns                  # For printing columns name or heading.
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
data.index                      # used to check how many rows in data frame means how many index.
# Out:
# RangeIndex(start=0, stop=201, step=1)

# %%
data.isnull()                               # It's printing in booleans forms (True or False)
# Out:
#      symboling  normalized_losses   make  fuel_type  aspiration  \
# 0        False              False  False      False       False
# 1        False              False  False      False       False
# 2        False              False  False      False       False
# 3        False              False  False      False       False
# 4        False              False  False      False       False
# ..         ...                ...    ...        ...         ...
# 196      False              False  False      False       False
# 197      False              False  False      False       False
# 198      False              False  False      False       False
# 199      False              False  False      False       False
# 200      False              False  False      False       False
#
#      number_of_doors  body_style  drive_wheels  engine_location  wheel_base  \
# 0              False       False         False            False       False
# ...

# %%
data.isnull().sum()                        # Printing total null value in dataset.
# Out:
# symboling              0
# normalized_losses      0
# make                   0
# fuel_type              0
# aspiration             0
# number_of_doors        0
# body_style             0
# drive_wheels           0
# engine_location        0
# wheel_base             0
# length                 0
# width                  0
# height                 0
# curb_weight            0
# engine_type            0
# number_of_cylinders    0
# engine_size            0
# fuel_system            0
# bore                   0
# stroke                 0
# compression_ratio      0
# horsepower             0
# peak_rpm               0
# city_mpg               0
# highway_mpg            0
# price                  0
# dtype: int64

# %% [markdown]
# **Difference Between isnull() and isna()**
#
# The two DataFrame methods do exactly the same thing! Even their docs are identical. You can even confirm this in pandas code.
#
# But why have two methods with different names do the same thing? This is beacuse pandas DataFrame are based on R's DataFrame. In R **na** and **null** are two separate things.
#
# However, in python, pandas is built in top of numpy, which has neither **na** nor **null** values. Instead numpy has NaN values (Which stand for "NOT a NUMBER"). Consequently, pandas also uses NaN values.
#
# In short To detect NaN values numpy used **np.isnan().**
#
# To detect NaN values pandas uses either **.isna()** or **.isnull()**. The NaN values are inherited from the fact thet pandas is built on top of numpy, while the two functions names originate from R's DataFrame, whose structure and functionality pandas tried to mimic.

# %%
# data.dropna()              # used dropna() to drop any NaN in the dataset

# %%
data.describe()                               # Use T for tansfer row into columes.
# Out:
#         symboling  normalized_losses  wheel_base      length       width  \
# count  201.000000         201.000000  201.000000  201.000000  201.000000
# mean     0.840796         125.189055   98.797015  174.200995   65.889055
# std      1.254802          33.572966    6.066366   12.322175    2.101471
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.800000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.500000   66.600000
# max      3.000000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb_weight  engine_size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean    53.766667  2555.666667   126.875622    3.329701    3.261741
# std      2.447822   517.296727    41.546834    0.268166    0.317875
# ...

# %%
data.describe().T                 # Gives the 5 Number summary of the dataframe
# Out:
#                    count          mean          std      min      25%  \
# symboling          201.0      0.840796     1.254802    -2.00     0.00
# normalized_losses  201.0    125.189055    33.572966    65.00   101.00
# wheel_base         201.0     98.797015     6.066366    86.60    94.50
# length             201.0    174.200995    12.322175   141.10   166.80
# width              201.0     65.889055     2.101471    60.30    64.10
# height             201.0     53.766667     2.447822    47.80    52.00
# curb_weight        201.0   2555.666667   517.296727  1488.00  2169.00
# engine_size        201.0    126.875622    41.546834    61.00    98.00
# bore               201.0      3.329701     0.268166     2.54     3.15
# stroke             201.0      3.261741     0.317875     2.07     3.11
# compression_ratio  201.0     10.164279     4.004965     7.00     8.60
# horsepower         201.0    103.263682    37.389372    48.00    70.00
# ...

# %% [markdown]
# ## Let's perform some conditional selections

# %%
data.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
data['price']
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 196    16845
# 197    19045
# 198    21485
# 199    22470
# 200    22625
# Name: price, Length: 201, dtype: int64

# %%
data['price'].max()
# Out:
# 45400

# %% [markdown]
# ### prices > 40000

# %%
data['price']>40000           # It's gave output in boolean form.
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 196    False
# 197    False
# 198    False
# 199    False
# 200    False
# Name: price, Length: 201, dtype: bool

# %%
data[data['price']>40000]                  # prices > 40,000
# Out:
#     symboling  normalized_losses           make fuel_type aspiration  \
# 15          0                149            bmw       gas        std
# 70          0                140  mercedes-benz       gas        std
# 71          1                140  mercedes-benz       gas        std
#
#    number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 15             two      sedan          rwd           front       103.5  ...
# 70            four      sedan          rwd           front       120.9  ...
# 71             two    hardtop          rwd           front       112.0  ...
#
#     engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 15          209         mpfi  3.62    3.39               8.0        182
# 70          308         mpfi  3.80    3.35               8.0        184
# 71          304         mpfi  3.80    3.35               8.0        184
#
#     peak_rpm city_mpg  highway_mpg  price
# 15      5400       16           22  41315
# ...

# %%
data[data["price"]>20000][['make','price']]            # which car is having the price greater then 20,000
# Out:
#               make  price
# 8             audi  23875
# 11             bmw  20970
# 12             bmw  21105
# 13             bmw  24565
# 14             bmw  30760
# 15             bmw  41315
# 16             bmw  36880
# 44          jaguar  32250
# 45          jaguar  35550
# 46          jaguar  36000
# 64   mercedes-benz  25552
# 65   mercedes-benz  28248
# 66   mercedes-benz  28176
# 67   mercedes-benz  31600
# 68   mercedes-benz  34184
# 69   mercedes-benz  35056
# 70   mercedes-benz  40960
# 71   mercedes-benz  45400
# 122        porsche  22018
# 123        porsche  32528
# 124        porsche  34028
# 125        porsche  37028
# 198          volvo  21485
# 199          volvo  22470
# 200          volvo  22625

# %%
data[(data['make']=='volvo') & (data['price']<50000)][['make','price']]               # All the volvo cars that are priced less than 50,000
# Out:
#       make  price
# 190  volvo  12940
# 191  volvo  13415
# 192  volvo  15985
# 193  volvo  16515
# 194  volvo  18420
# 195  volvo  18950
# 196  volvo  16845
# 197  volvo  19045
# 198  volvo  21485
# 199  volvo  22470
# 200  volvo  22625

# %%
# In above program use == for equality, and [[]] use for only those columns print.
